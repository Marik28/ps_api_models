# %%
import pandas as pd
import json
import numpy as np

# %%
with open("data/all_products.json", encoding="utf-8") as f:
    data = json.load(f)

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#                                   name   platforms typename  \
# 0                           Weird West       [PS4]  Product
# 1              SpellForce III Reforced       [PS4]  Product
# 2              Horizon Запретный Запад       [PS4]  Product
# 3     Dying Light 2 Stay Human PS4&PS5       [PS4]  Product
# 4                Arcade Archives XEXEX       [PS4]  Product
# ...                                ...         ...      ...
# 4998     Concept Destruction PS4 & PS5  [PS4, PS5]  Product
# 4999          Infliction: Extended Cut  [PS4, PS5]  Product
# 5000          A Plague Tale: Innocence       [PS4]  Product
# 5001              Subnautica PS4 & PS5  [PS4, PS5]  Product
# 5002                      Energy Cycle  [PS4, PS5]  Product
#
#                                         id   np_title_id  \
# 0     EP3643-CUSA17337_00-WEIRDWESTPS4EU00  CUSA17337_00
# 1     EP4389-CUSA24277_00-SPELLFORCE3PS4EU  CUSA24277_00
# 2     EP9000-CUSA24705_00-FORBIDDENWESTPS4  CUSA24705_00
# 3     EP2911-CUSA12555_00-DYINGLIGHT2GAMEU  CUSA12555_00
# 4     EP8908-CUSA30637_00-HAMPRDC000000001  CUSA30637_00
# ...                                    ...           ...
# 4998  EP0896-CUSA18965_00-RATACONCEPTDESTR  CUSA18965_00
# 4999  EP5733-CUSA15744_00-INFLICTIONPS4000  CUSA15744_00
# 5000  EP4133-CUSA10812_00-APLAGUETALEGAME0  CUSA10812_00
# 5001  EP5426-CUSA13893_00-2222444466669999  CUSA13893_00
# 5002  EP1661-CUSA08166_00-SYPS4ENERGYCYCLE  CUSA08166_00
#
#      localized_store_display_classification  \
# 0                        Полная версия игры
# 1                        Полная версия игры
# 2                        Полная версия игры
# 3                        Полная версия игры
# 4                        Полная версия игры
# ...                                     ...
# 4998                     Полная версия игры
# 4999                     Полная версия игры
# 5000                     Полная версия игры
# 5001                     Полная версия игры
# 5002                     Полная версия игры
#
#                                                   media  \
# 0     [{'typename': 'Media', 'type': 'IMAGE', 'url':...
# 1     [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# 2     [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# 3     [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# 4     [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# ...                                                 ...
# 4998  [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# 4999  [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# 5000  [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# 5001  [{'typename': 'Media', 'type': 'VIDEO', 'url':...
# 5002  [{'typename': 'Media', 'type': 'VIDEO', 'url':...
#
#                                                    skus price.typename  \
# 0             [{'typename': 'Sku', 'type': 'PREORDER'}]       SkuPrice
# 1             [{'typename': 'Sku', 'type': 'PREORDER'}]       SkuPrice
# 2             [{'typename': 'Sku', 'type': 'PREORDER'}]       SkuPrice
# 3             [{'typename': 'Sku', 'type': 'PREORDER'}]       SkuPrice
# 4             [{'typename': 'Sku', 'type': 'STANDARD'}]       SkuPrice
# ...                                                 ...            ...
# 4998          [{'typename': 'Sku', 'type': 'STANDARD'}]       SkuPrice
# 4999  [{'typename': 'Sku', 'type': 'STANDARD'}, {'ty...       SkuPrice
# 5000          [{'typename': 'Sku', 'type': 'STANDARD'}]       SkuPrice
# 5001  [{'typename': 'Sku', 'type': 'STANDARD'}, {'ty...       SkuPrice
# 5002          [{'typename': 'Sku', 'type': 'STANDARD'}]       SkuPrice
#
#      price.base_price price.discounted_price price.is_free  \
# 0           RUB 2.849              RUB 2.849         False
# 1           RUB 2.849              RUB 2.849         False
# 2           RUB 4.999              RUB 4.999         False
# 3           RUB 4.279              RUB 4.279         False
# 4             RUB 644                RUB 644         False
# ...               ...                    ...           ...
# 4998          RUB 359                RUB 359         False
# 4999        RUB 1.289              RUB 1.289         False
# 5000        Бесплатно              Бесплатно          True
# 5001        RUB 2.149              RUB 1.074         False
# 5002          RUB 249                RUB 249         False
#
#      price.is_tied_to_subscription price.is_exclusive price.discount_text  \
# 0                            False              False                None
# 1                            False              False                None
# 2                            False              False                None
# 3                            False              False                None
# 4                            False              False                None
# ...                            ...                ...                 ...
# 4998                         False              False                None
# 4999                         False              False                None
# 5000                         False              False                None
# 5001                         False              False                -50%
# 5002                         False              False                None
#
#      price.service_branding price.upsell_service_branding price.upsell_text  \
# 0                        []                          None              None
# 1                        []                          None              None
# 2                        []                          None              None
# 3                        []                          None              None
# 4                        []                          None              None
# ...                     ...                           ...               ...
# 4998                     []                          None              None
# 4999                     []                          None              None
# 5000                     []                          None              None
# 5001                     []                          None              None
# 5002                     []                          None              None
#
#       price
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 4998    NaN
# 4999    NaN
# 5000    NaN
# 5001    NaN
# 5002    NaN
#
# [5003 rows x 19 columns]

# %%
# вынесем media в отдельный датафрейм

# %%
media = df["media"]

# %%
# уберем бесполезные столбцы

# %%
df = df.drop(columns=["price.typename", "price", "typename", "media"])

# %%
df
# Out:
#                                   name   platforms  \
# 0                           Weird West       [PS4]
# 1              SpellForce III Reforced       [PS4]
# 2              Horizon Запретный Запад       [PS4]
# 3     Dying Light 2 Stay Human PS4&PS5       [PS4]
# 4                Arcade Archives XEXEX       [PS4]
# ...                                ...         ...
# 4998     Concept Destruction PS4 & PS5  [PS4, PS5]
# 4999          Infliction: Extended Cut  [PS4, PS5]
# 5000          A Plague Tale: Innocence       [PS4]
# 5001              Subnautica PS4 & PS5  [PS4, PS5]
# 5002                      Energy Cycle  [PS4, PS5]
#
#                                         id   np_title_id  \
# 0     EP3643-CUSA17337_00-WEIRDWESTPS4EU00  CUSA17337_00
# 1     EP4389-CUSA24277_00-SPELLFORCE3PS4EU  CUSA24277_00
# 2     EP9000-CUSA24705_00-FORBIDDENWESTPS4  CUSA24705_00
# 3     EP2911-CUSA12555_00-DYINGLIGHT2GAMEU  CUSA12555_00
# 4     EP8908-CUSA30637_00-HAMPRDC000000001  CUSA30637_00
# ...                                    ...           ...
# 4998  EP0896-CUSA18965_00-RATACONCEPTDESTR  CUSA18965_00
# 4999  EP5733-CUSA15744_00-INFLICTIONPS4000  CUSA15744_00
# 5000  EP4133-CUSA10812_00-APLAGUETALEGAME0  CUSA10812_00
# 5001  EP5426-CUSA13893_00-2222444466669999  CUSA13893_00
# 5002  EP1661-CUSA08166_00-SYPS4ENERGYCYCLE  CUSA08166_00
#
#      localized_store_display_classification  \
# 0                        Полная версия игры
# 1                        Полная версия игры
# 2                        Полная версия игры
# 3                        Полная версия игры
# 4                        Полная версия игры
# ...                                     ...
# 4998                     Полная версия игры
# 4999                     Полная версия игры
# 5000                     Полная версия игры
# 5001                     Полная версия игры
# 5002                     Полная версия игры
#
#                                                    skus price.base_price  \
# 0             [{'typename': 'Sku', 'type': 'PREORDER'}]        RUB 2.849
# 1             [{'typename': 'Sku', 'type': 'PREORDER'}]        RUB 2.849
# 2             [{'typename': 'Sku', 'type': 'PREORDER'}]        RUB 4.999
# 3             [{'typename': 'Sku', 'type': 'PREORDER'}]        RUB 4.279
# 4             [{'typename': 'Sku', 'type': 'STANDARD'}]          RUB 644
# ...                                                 ...              ...
# 4998          [{'typename': 'Sku', 'type': 'STANDARD'}]          RUB 359
# 4999  [{'typename': 'Sku', 'type': 'STANDARD'}, {'ty...        RUB 1.289
# 5000          [{'typename': 'Sku', 'type': 'STANDARD'}]        Бесплатно
# 5001  [{'typename': 'Sku', 'type': 'STANDARD'}, {'ty...        RUB 2.149
# 5002          [{'typename': 'Sku', 'type': 'STANDARD'}]          RUB 249
#
#      price.discounted_price price.is_free price.is_tied_to_subscription  \
# 0                 RUB 2.849         False                         False
# 1                 RUB 2.849         False                         False
# 2                 RUB 4.999         False                         False
# 3                 RUB 4.279         False                         False
# 4                   RUB 644         False                         False
# ...                     ...           ...                           ...
# 4998                RUB 359         False                         False
# 4999              RUB 1.289         False                         False
# 5000              Бесплатно          True                         False
# 5001              RUB 1.074         False                         False
# 5002                RUB 249         False                         False
#
#      price.is_exclusive price.discount_text price.service_branding  \
# 0                 False                None                     []
# 1                 False                None                     []
# 2                 False                None                     []
# 3                 False                None                     []
# 4                 False                None                     []
# ...                 ...                 ...                    ...
# 4998              False                None                     []
# 4999              False                None                     []
# 5000              False                None                     []
# 5001              False                -50%                     []
# 5002              False                None                     []
#
#      price.upsell_service_branding price.upsell_text
# 0                             None              None
# 1                             None              None
# 2                             None              None
# 3                             None              None
# 4                             None              None
# ...                            ...               ...
# 4998                          None              None
# 4999                          None              None
# 5000                          None              None
# 5001                          None              None
# 5002                          None              None
#
# [5003 rows x 15 columns]

# %%
def to_1D(series):
    """Делает плоский массив из всех элементов переданных массивов"""
    return pd.Series([x for _list in series for x in _list])

# %%
from typing import Iterable

def boolean_df(item_lists: pd.DataFrame, unique_items: Iterable[str]):
    """Возвращает датафрейм со столбцами из `unique_items` типа bool для каждей записи"""
# Create empty dict
    bool_dict = {}
    
    # Loop through all the tags
    for item in unique_items:
        
        # Apply boolean mask
        bool_dict[item] = item_lists.apply(lambda x: item in x)
    # Return the results as a dataframe
    return pd.DataFrame(bool_dict)

# %%
from typing import Optional
import re

def parse_price(text) -> int:
    """
    Парсит цену из строки по типу 'CURRENCY PRICE'
    Если передать numpy.nan или не удалось распарсить, вернет numpy.nan
    
    >>> parse_price("RUB 1.015")
    1015
    
    (text) -> price
    """
    if not isinstance(text, str) and np.isnan(text):
        return np.nan
    price_pattern = re.compile(r"^(?P<currency>\w+)\s+(?P<price>[\d.]*)$")
    result = price_pattern.match(text)

    if result is not None:
        price = int(result.group("price").replace(".", ""))
        return price

    return np.nan

# %%
def replace_nan_with_empty_list(df: pd.DataFrame) -> pd.DataFrame:
    """Принимает столбец с со списками, заменяет все NaN-подобные значения пустыми списками"""
    return df.fillna("").apply(list)

# %%
# добавим столбик "PREORDER", распарсив "skus"

# %%
skus = df["skus"].apply(lambda skus: [sku["type"] for sku in skus]).to_frame().rename(columns={"skus": "types"})

# %%
skus = boolean_df(skus["types"], to_1D(skus["types"]).unique())

# %%
df = df.join(skus["PREORDER"]).drop(columns=["skus"])

# %%
df["price.upsell_service_branding"] = replace_nan_with_empty_list(df["price.upsell_service_branding"])

# %%
# Достанем из столбца "price.upsell_service_branding" уникальные значения и сделаем из них отдельные столбцы

# %%
brandings_df = boolean_df(df["price.upsell_service_branding"], to_1D(df["price.upsell_service_branding"]).unique())

# %%
brandings_df
# Out:
#       PS_PLUS  EA_ACCESS
# 0       False      False
# 1       False      False
# 2       False      False
# 3       False      False
# 4       False      False
# ...       ...        ...
# 4998    False      False
# 4999    False      False
# 5000    False      False
# 5001    False      False
# 5002    False      False
#
# [5003 rows x 2 columns]

# %%
df = df.join(brandings_df).drop(columns=["price.upsell_service_branding"])

# %%
df = df["price.upsell_text"].fillna("")

# %%
df
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 4998
# 4999
# 5000
# 5001
# 5002
# Name: price.upsell_text, Length: 5003, dtype: object

# %%
df.localized_store_display_classification.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11600/438750842.py in <module>
# ----> 1 df.localized_store_display_classification.unique()
#
# ~\PycharmProjects\ps_api_models\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'localized_store_display_classification'

# %%
# нормализуем столбец "price.discount_text" для парсинга

# %%
df["price.discount_text"] = df["price.discount_text"].fillna("-0%").apply(lambda x: int(x[1:-1])).to_frame().rename(columns={"price.discount_text": "discount"})

# %%
# нормализуем столбец "price.is_tied_to_subscription"

# %%
df["price.is_tied_to_subscription"] = df["price.is_tied_to_subscription"].fillna(False)

# %%
# нормализуем столбец "price.is_exclusive"

# %%
df["price.is_exclusive"] = df["price.is_exclusive"].fillna(False)

# %%
# извлечем уникальные значения из "platforms"

# %%
platforms_df = boolean_df(df["platforms"],  to_1D(df["platforms"]).unique())

# %%
platforms_df

# %%
df = df.drop(columns=["platforms"]).join(platforms_df)

# %%
df[(df["PS4"] == True) & (df["PS5"] == True)]

# %%
# нормализуем столбец "price.service_branding", заменив null-значения пустыми списками

# %%
df["price.service_branding"] = replace_nan_with_empty_list(df["price.service_branding"])

# %%
# извлечем уникальные значения из "price.service_branding"

# %%
service_brandings = boolean_df(df["price.service_branding"], to_1D(df["price.service_branding"]).unique()).rename(columns={"EA_ACCESS": "EA_ACCESS_2"})

# %%
df = df.join(service_brandings).drop(columns=["price.service_branding"])

# %%
df[df["UPGRADE"] == True]["name"]

# %%
# нормализуем столбец "price.base_price"

# %%
df["price.base_price"] = df["price.base_price"].replace(["Бесплатно", "Недоступно"], ["RUB 0", np.nan])

# %%
# нормализуем столбец "price.discounted_price"

# %%
df["price.discounted_price"] = df["price.discounted_price"].replace(["Бесплатно", "Входит в подписку", "Недоступно"], ["RUB 0", "RUB 0", np.nan])

# %%
# распарсим числовые значения из столбца "price.base_price"

# %%
df["price.base_price"] = df["price.base_price"].apply(parse_price)

# %%
# распарсим числовые значения из столбца "price.discounted_price"

# %%
df["price.discounted_price"] = df["price.discounted_price"].apply(parse_price)

# %%
# дропнем явные дубликаты

# %%
df = df.drop_duplicates()

# %%
len(df["id"].unique())

# %%
len(df["np_title_id"].unique())

# %%
df

# %%
df[(df["price.upsell_text"] == "Входит в подписку") & df["PS_PLUS"] == True][["price.upsell_text", "PS_PLUS", "UPGRADE"]]

# %%
grouped_df = df[["name", "id", "np_title_id"]].groupby(["name"]).count()

# %%
grouped_df[grouped_df["id"] >= 2]

# %%
df

# %%
df["price.upsell_text"].unique()
